# %%
# !pip install OpenNMT-py
# Out:
# ...
#      |████████████████████████████████| 204kB 4.3MB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 61kB 8.2MB/s
# ...
#      |████████████████████████████████| 61kB 7.9MB/s
# ...
#      |████████████████████████████████| 2.6MB 12.5MB/s
# ...
#   Created wheel for configargparse: filename=ConfigArgParse-1.2.3-cp36-none-any.whl size=19329 sha256=517777e4bb5a860511caa1ba35723e30b9a853d2fad7845d715a0d81377ed018
#   Stored in directory: /root/.cache/pip/wheels/bd/d6/53/034032da9498bda2385cd50a51a289e88090b5da2d592b1fdf
# Successfully built configargparse
# ...
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# ...

# %%
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# Out:
# Cloning into 'OpenNMT-py'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 16245 (delta 13), reused 12 (delta 5), pack-reused 16210
# Receiving objects: 100% (16245/16245), 146.92 MiB | 13.73 MiB/s, done.
# Resolving deltas: 100% (11741/11741), done.

# %%
# !onmt_preprocess -train_src src-train-bpe.txt -train_tgt tgt-train-bpe.txt -valid_src src-val-bpe.txt -valid_tgt tgt-val-bpe.txt -save_data demo
# Out:
# [2020-10-21 18:52:42,351 INFO] Extracting features...
# [2020-10-21 18:52:42,351 INFO]  * number of source features: 0.
# [2020-10-21 18:52:42,352 INFO]  * number of target features: 0.
# [2020-10-21 18:52:42,352 INFO] Building `Fields` object...
# [2020-10-21 18:52:42,352 INFO] Building & saving training data...
# [2020-10-21 18:52:45,154 INFO] Building shard 0.
# [2020-10-21 18:53:31,687 INFO]  * saving 0th train data shard to demo.train.0.pt.
# [2020-10-21 18:53:59,026 INFO] Building shard 1.
# [2020-10-21 18:54:33,623 INFO]  * saving 1th train data shard to demo.train.1.pt.
# tcmalloc: large alloc 1073741824 bytes == 0x7eeb0000 @  0x7febd92261e7 0x5acbbb 0x4e05c6 0x4e1ea0 0x4e239f 0x4e2e84 0x4e2a04 0x4e0ea8 0x4e263b 0x4e24af 0x4e2ab0 0x4e0ea8 0x4e263b 0x4e34a6 0x5eb622 0x50a51c 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x588e91
# [2020-10-21 18:55:00,773 INFO]  * tgt vocab size: 32093.
# ...

# %%
# !onmt_train -data BPE/demo -save_model demo-model -layers 6 -rnn_size 512 -word_vec_size 512 -transformer_ff 2048 -heads 8 -encoder_type transformer -decoder_type transformer -position_encoding -train_steps 200000 -max_generator_batches 2 -dropout 0.1 -batch_size 4096 -batch_type tokens -normalization tokens -accum_count 2 -optim adam -adam_beta2 0.998 -decay_method noam -warmup_steps 8000 -learning_rate 2 -max_grad_norm 0 -param_init 0 -param_init_glorot -label_smoothing 0.1 -valid_steps 200 -save_checkpoint_steps 1000  -train_from 'BPE/demo-model_step_50000.pt' -world_size 1 -gpu_rank 0
# Out:
# [2020-10-23 10:28:07,985 INFO] Loading checkpoint from BPE/demo-model_step_50000.pt
# [2020-10-23 10:28:08,723 INFO] Loading vocab from checkpoint at BPE/demo-model_step_50000.pt.
# [2020-10-23 10:28:08,798 INFO]  * src vocab size = 23238
# [2020-10-23 10:28:08,798 INFO]  * tgt vocab size = 32093
# [2020-10-23 10:28:08,798 INFO] Building model...
# [2020-10-23 10:28:19,655 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(23238, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (transformer): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp "/content/demo-model_step_50000.pt" "/content/gdrive/My Drive/BPE/"

# %%
# !cp -a "/content/drive/My Drive/BPE"  /content/

# %%
# !onmt_translate -model BPE/demo-model_step_50000.pt -src BPE/src-test-bpe.txt -output pred.txt -replace_unk -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# PRED 1508: ▁हो वी ▁को ▁भी ▁90 % ▁की ▁लागत ▁का ▁भुगतान ▁करने ▁का ▁आदेश ▁दिया ▁गया ▁था ▁और ▁100 ▁का ▁एक ▁पीड़ित ▁अधिभार ▁भी ▁दिया ▁गया ▁था ।
# PRED SCORE: -16.7451
#
# [2020-10-23 11:01:36,292 INFO]
# SENT 1509: ['▁tax', '▁on', '▁foreign', '▁property', '▁owners', '▁to', '▁burst', '▁l', 'ond', 'ons', '▁bubble']
# PRED 1509: ▁लॉ न्ड न ▁बुलबु ले ▁फटने ▁के ▁लिए ▁विदेशी ▁संपत्ति ▁मालिकों ▁पर ▁कर
# PRED SCORE: -8.3896
#
# [2020-10-23 11:01:36,292 INFO]
# ...

# %%
# !perl  OpenNMT-py/tools/multi-bleu.perl test.hi < real_pred.txt
# Out:
# Can't open perl script "OpenNMT-py/tools/multi-bleu.perl": No such file or directory
